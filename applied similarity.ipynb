# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('ERS_DATASET.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0                            company  \
# 0           1  HANSUM INDIA ELECTRONICS PVT.LTD.
# 1           2                            Premium
# 2           3                    R3 Plant Design
#
#                                            education  experience  \
# 0  UG: Diploma - Any Specialization, Electronics/...           1
# 1  UG: Any Graduate - Any Specialization PG:Any P...           1
# 2  UG: B.Tech/B.E. - Mechanical, Mineral, Mining,...           3
#
#                                        industry  \
# 0  ['Industrial Products ', ' Heavy Machinery']
# 1             ['FMCG ', ' Foods ', ' Beverage']
# 2  ['Industrial Products ', ' Heavy Machinery']
#
#                                       jobdescription  jobid  \
# 0  pend handl entir product line 30 employees. ha...   9904
# 1  tray product-start-up help restaur market, eng...   7705
# 2  descript : interest real mechan design.. If So...   9909
#
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#                              company  \
# 0  HANSUM INDIA ELECTRONICS PVT.LTD.
# 1                            Premium
# 2                    R3 Plant Design
#
#                                            education  experience  \
# 0  UG: Diploma - Any Specialization, Electronics/...           1
# 1  UG: Any Graduate - Any Specialization PG:Any P...           1
# 2  UG: B.Tech/B.E. - Mechanical, Mineral, Mining,...           3
#
#                                        industry  \
# 0  ['Industrial Products ', ' Heavy Machinery']
# 1             ['FMCG ', ' Foods ', ' Beverage']
# 2  ['Industrial Products ', ' Heavy Machinery']
#
#                                       jobdescription  jobid  \
# 0  pend handl entir product line 30 employees. ha...   9904
# 1  tray product-start-up help restaur market, eng...   7705
# 2  descript : interest real mechan design.. If So...   9909
#
#                   joblocation_address                      jobtitle  \
# ...

# %%
d=df[['jobtitle','skills','jobdescription']]

# %%
len(d)
# Out:
# 2015

# %%
d['skills'][0]
# Out:
# 'Production'

# %%
d['skills']
# Out:
# 0                                              Production
# 1       strategic skills ms office teamwork communicat...
# 2                                      Engineering Design
# 3                   IT Software - Application Programming
# 4                   IT Software - Application Programming
#                               ...
# 2010    marketing communication skills planning abilit...
# 2011    marketing communication skills planning abilit...
# 2012                                                Sales
# 2013                                 IT Software - Mobile
# 2014                                                Sales
# Name: skills, Length: 2015, dtype: object

# %%
ls=[]
for i in d['skills']:
    ls.append(str(i).lower())

# %%
ls[1]
# Out:
# 'strategic skills ms office teamwork communication skills marketing'

# %%
d['skills']=ls
# Out:
# C:\Users\HARSHIT\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_jaccard_sim(str1, str2):              #jacard similarity
    a = set(str1.split()) 
    b = set(str2.split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
lps=[]
test="java web teamwork php"
for j in range(len(d)):
    lps.append(get_jaccard_sim(test,d.jobdescription[j]))

# %%
d['jacard'] = lps
g = set(lps)
final = list(g)
final.sort(reverse=True)
# Out:
# C:\Users\HARSHIT\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d.head(3)
# Out:
#                        jobtitle  \
# 0                   Team Leader
# 1  Business Development Manager
# 2               Design Engineer
#
#                                               skills  \
# 0                                         production
# 1  strategic skills ms office teamwork communicat...
# 2                                 engineering design
#
#                                       jobdescription  jacard
# 0  pend handl entir product line 30 employees. ha...     0.0
# 1  tray product-start-up help restaur market, eng...     0.0
# 2  descript : interest real mechan design.. If So...     0.0

# %%
t=[]
y=[]
l=[]
for i in range(len(final)-1):
    t = d[d['jacard']==final[i]].jobtitle
    r = set(t)
    y.append(list(r))


y=list(y)

print("You can apply for the following Job Profiles :")
for i in range(len(y)):
    if i==10:
        break
    #print(i+1," - ",y[i][0])
    l.append(y[i][0])
s=set(l)
s=list(s)
for i in range(len(s)):
    print(i+1," - ",s[i])
# Out:
# You can apply for the following Job Profiles :
# 1  -  Java Developers
# 2  -  Java Developer
# 3  -  Senior Software Engineer
# 4  -  Web Developer
# 5  -  Php Developer
# 6  -  ANDROID DEVELOPER
# 7  -  PHP Developer

# %%
d.head(3)
# Out:
#                        jobtitle  \
# 0                   Team Leader
# 1  Business Development Manager
# 2               Design Engineer
#
#                                               skills  \
# 0                                         production
# 1  strategic skills ms office teamwork communicat...
# 2                                 engineering design
#
#                                       jobdescription  jacard
# 0  pend handl entir product line 30 employees. ha...     0.0
# 1  tray product-start-up help restaur market, eng...     0.0
# 2  descript : interest real mechan design.. If So...     0.0

# %%
d.drop(['jacard'],axis=1,inplace=True)
# Out:
# C:\Users\HARSHIT\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
d.head(3)
# Out:
#                        jobtitle  \
# 0                   Team Leader
# 1  Business Development Manager
# 2               Design Engineer
#
#                                               skills  \
# 0                                         production
# 1  strategic skills ms office teamwork communicat...
# 2                                 engineering design
#
#                                       jobdescription
# 0  pend handl entir product line 30 employees. ha...
# 1  tray product-start-up help restaur market, eng...
# 2  descript : interest real mechan design.. If So...

# %%
d.head(3)
# Out:
#                        jobtitle  \
# 0                   Team Leader
# 1  Business Development Manager
# 2               Design Engineer
#
#                                               skills  \
# 0                                         production
# 1  strategic skills ms office teamwork communicat...
# 2                                 engineering design
#
#                                       jobdescription
# 0  pend handl entir product line 30 employees. ha...
# 1  tray product-start-up help restaur market, eng...
# 2  descript : interest real mechan design.. If So...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
TfidfVec = TfidfVectorizer()
def cos_similarity(textlist):
    tfidf = TfidfVec.fit_transform(textlist)
    return (tfidf * tfidf.T).toarray()

# %%
#des1="I required java developer, Android and web dev for my project java"
#des2="I like java,web and Android "

#docs=[des1,des2]

lps=[]
test="python machine learning data science django deep learning"
for j in range(len(d)):
    sim=cos_similarity([test,d.jobdescription[j]])
    lps.append(sim[0][1])


#cos_similarity(docs)

# %%
type(lps)
# Out:
# list

# %%
d['cosin'] = lps
g = set(lps)
final = list(g)
final.sort(reverse=True)
# Out:
# C:\Users\HARSHIT\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
t=[]
y=[]
l=[]
for i in range(len(final)-1):
    t = d[d['cosin']==final[i]].jobtitle
    r = set(t)
    y.append(list(r))


y=list(y)

print("You can apply for the following Job Profiles :")
for i in range(len(y)):
    if i==10:
        break
    #print(i+1," - ",y[i][0])
    l.append(y[i][0])
s=set(l)
s=list(s)
for i in range(len(s)):
    print(i+1," - ",s[i])
# Out:
# You can apply for the following Job Profiles :
# 1  -  Python Developer
# 2  -  Software Engineer
# 3  -  Senior Software Engineer
# 4  -  Data Analyst
# 5  -  Senior Analyst
# 6  -  Business Analyst

# %%
t
# Out:
# 1453    Associate Consultant
# Name: jobtitle, dtype: object

# %%
l=set(l)

# %%
l
# Out:
# {'Business Analyst',
#  'Data Analyst',
#  'Python Developer',
#  'Senior Analyst',
#  'Senior Software Engineer',
#  'Software Engineer'}

# %%
skill_set=["python machine learning data science django deep learning","java android flutter app dev","python programming coding"
           ,"full stack","html css bootstrap"]
